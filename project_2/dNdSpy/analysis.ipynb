# %%
# main_script_debug.py
import os
import pandas as pd

# Import necessary modules
# Make sure these point to the updated files with debug prints
from data_classes import parse_maf_file, ReferenceGenome, GeneAnnotation
from dnds_analysis import DnDsAnalysis

# --- Configuration ---
MAF_FILE = "/Users/xbh0403/Desktop/25SP/BENG285/project_2/TCGA.LUAD.mutations.txt"
FASTA_FILE = "/Users/xbh0403/Desktop/25SP/BENG285/project_2/hg19.fa"
GTF_FILE = "/Users/xbh0403/Desktop/25SP/BENG285/project_2/gencode.v19.annotation.gtf"
OUTPUT_DIR = "results_directory_debug_final_3"
HYPERMUTATOR_THRESHOLD = 500
FDR_THRESHOLD = 0.1

mutation_data = parse_maf_file(MAF_FILE)
filtered_data, hypermutators = mutation_data.filter_hypermutators(threshold=HYPERMUTATOR_THRESHOLD)
ref_genome = ReferenceGenome(FASTA_FILE)
gene_annotation = GeneAnnotation(GTF_FILE)
dnds_analysis = DnDsAnalysis(
    mutation_dataset=filtered_data,
    reference_genome=ref_genome,
    gene_annotation=gene_annotation,
    covariates_df=None # Keep as None if not using covariates
)
# Out:
# Debug (ParseMAF): Creating MutationDataset and calling load_from_maf for /Users/xbh0403/Desktop/25SP/BENG285/project_2/TCGA.LUAD.mutations.txt
# Debug (MAF Load): Reading MAF file: /Users/xbh0403/Desktop/25SP/BENG285/project_2/TCGA.LUAD.mutations.txt
# Debug (MAF Load): Read 224373 rows from MAF.
# Debug (MAF Load): Processing 224373 rows...
# Debug (MAF Load): Finished processing. Added 224373 mutations.
# Debug (ParseMAF): load_from_maf finished. Dataset summary: MutationDataset: 224373 mutations in 18718 genes from 512 samples
# Debug (FilterHyper): Checking for hypermutators (threshold > 500 mutations/sample)...
# Debug (FilterHyper): Found 158 hypermutator samples: ['TCGA-05-4382', 'TCGA-05-4390', 'TCGA-05-4396', 'TCGA-05-4397', 'TCGA-05-4398']...
# Debug (FilterHyper): Creating new dataset excluding hypermutators...
# Debug (FilterHyper): New dataset created with 71477 mutations from 354 samples.
# Debug (RefGenome): pysam loaded successfully. Found 93 contigs.
#
# Debug (GeneAnnotation): Finished reading GTF. Processed 723784 CDS lines.
# Debug (GeneAnnotation): Aggregating data for 20673 unique gene names...
# Debug (GeneAnnotation): Successfully processed and stored annotation for 20673 genes.
# Debug (Analysis.__init__): Initializing DnDsAnalysis...
# Debug (Analysis.__init__): Initializing component models...
# Debug (TrinucModel): ctx_to_idx map initialized with 16 keys (e.g., ['ANA', 'ANC', 'ANG', 'ANT', 'CNA']...).
# Debug (TrinucModel): Initialized TrinucleotideModel.
# Debug (Calculator.__init__): Initializing DnDsCalculator...
# Debug (Calculator.__init__): DnDsCalculator initialization complete.
# Debug (Analysis.__init__): DnDsAnalysis initialization complete.

# %%
# --- Step 6: Run Analysis ---
print("\n--- Debug: Starting dN/dS Analysis Run ---")
try:
    # Create output directory if it doesn't exist
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    print(f"Debug: Results will be saved to: {OUTPUT_DIR}")

    results = dnds_analysis.run_analysis(
        output_dir=OUTPUT_DIR,
        hypermutator_threshold=HYPERMUTATOR_THRESHOLD, # Note: Filtering already done, but param is kept
        fdr_threshold=FDR_THRESHOLD
    )

except Exception as e:
    print(f"\nDebug: ERROR during dnds_analysis.run_analysis: {e}")
    import traceback
    traceback.print_exc() # Print detailed traceback
    exit()

print("\n--- Debug: Script Execution Complete ---")

# Close the reference genome file if necessary
if ref_genome and hasattr(ref_genome, 'close'):
    ref_genome.close()
    print("Debug: Closed reference genome file.")
# Out:
# --- Debug: Starting dN/dS Analysis Run ---
# Debug: Results will be saved to: results_directory_debug_final_2
#
# --- Debug (Analysis.run): Starting dN/dS analysis run ---
# Debug (Analysis.run): Using provided dataset with 71477 mutations, 354 samples.
#
# Debug (Analysis.run): Step 2 - Fitting trinucleotide substitution model...
# Debug (Analysis.run): Using 71477 mutations from dataset to fit model.
# Debug (TrinucModel.fit): Starting model fitting...
# Debug (TrinucModel.fit): Processing 71477 mutations...
#   Debug (RefGenome.Fetch): Original chrom '10' not found, using 'chr10' instead.
#   --- Processed mutation 0/71477 (CPN1:10:101814119:G>C): Context='TGG', NormRef='C', NormAlt='G', NormCtx='CCA', Strand=1, SubKey='C>G'(idx=1), CtxKey='CNA'(idx=4)
#   Debug (RefGenome.Fetch): Original chrom '10' not found, using 'chr10' instead.
#   --- Processed mutation 1/71477 (MKI67:10:129902901:G>A): Context='TGT', NormRef='C', NormAlt='T', NormCtx='ACA', Strand=1, SubKey='C>T'(idx=2), CtxKey='ANA'(idx=0)
#   Debug (RefGenome.Fetch): Original chrom '10' not found, using 'chr10' instead.
#   Debug (Mutation.Ctx): Fetched context 'GTT' middle base mismatch ref 'TTACAC' for NEBL:10:21104601:TTACAC>- at 10:21104601. Returning None.
#   >>> Skipping mutation 2/71477 (NEBL:10:21104601:TTACAC>-): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   Debug (RefGenome.Fetch): Original chrom '10' not found, using 'chr10' instead.
#   --- Processed mutation 3/71477 (RP11-445N18.7:10:45652518:G>A): Context='AGA', NormRef='C', NormAlt='T', NormCtx='TCT', Strand=1, SubKey='C>T'(idx=2), CtxKey='TNT'(idx=15)
#   Debug (RefGenome.Fetch): Original chrom '10' not found, using 'chr10' instead.
#   --- Processed mutation 4/71477 (ERCC6:10:50667200:G>A): Context='CGG', NormRef='C', NormAlt='T', NormCtx='CCG', Strand=1, SubKey='C>T'(idx=2), CtxKey='CNG'(idx=6)
#   --- Processed mutation 5/71477 (DIP2C:10:532472:T>A): Context='CTG', NormRef='T', NormAlt='A', NormCtx='CTG', Strand=0, SubKey='T>A'(idx=3), CtxKey='CNG'(idx=6)
#   --- Processed mutation 6/71477 (HECTD2:10:93220277:C>A): Context='CCA', NormRef='C', NormAlt='A', NormCtx='CCA', Strand=0, SubKey='C>A'(idx=0), CtxKey='CNA'(idx=4)
#   --- Processed mutation 7/71477 (TLL2:10:98188477:G>T): Context='TGG', NormRef='C', NormAlt='A', NormCtx='CCA', Strand=1, SubKey='C>A'(idx=0), CtxKey='CNA'(idx=4)
#   --- Processed mutation 8/71477 (ATM:11:108199895:A>C): Context='CAA', NormRef='T', NormAlt='G', NormCtx='TTG', Strand=1, SubKey='T>G'(idx=5), CtxKey='TNG'(idx=14)
#   --- Processed mutation 9/71477 (USP28:11:113700072:G>T): Context='GGC', NormRef='C', NormAlt='A', NormCtx='GCC', Strand=1, SubKey='C>A'(idx=0), CtxKey='GNC'(idx=9)
#   --- Processed mutation 10/71477 (VWA5A:11:123995132:C>G): Context='TCA', NormRef='C', NormAlt='G', NormCtx='TCA', Strand=0, SubKey='C>G'(idx=1), CtxKey='TNA'(idx=12)
#   Debug (Mutation.Ctx): Fetched context 'ACT' middle base mismatch ref 'CTGGGTGCCAGTTGAACAT' for CYB561A3:11:61124041:CTGGGTGCCAGTTGAACAT>- at 11:61124041. Returning None.
#   >>> Skipping mutation 17/71477 (CYB561A3:11:61124041:CTGGGTGCCAGTTGAACAT>-): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   Debug (Mutation.Ctx): Fetched context 'TAA' middle base mismatch ref 'AACAGCAGAG' for CDK12:17:37618415:AACAGCAGAG>- at 17:37618415. Returning None.
#   >>> Skipping mutation 82/71477 (CDK12:17:37618415:AACAGCAGAG>-): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 125/71477 (IARS2:1:220267786:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   Debug (Mutation.Ctx): Fetched context 'ATG' middle base mismatch ref '-' for GBP4:1:89662952:->G at 1:89662952. Returning None.
#   >>> Skipping mutation 140/71477 (GBP4:1:89662952:->G): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 147/71477 (LINC00478:21:17443512:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   Debug (Mutation.Ctx): Fetched context 'CTC' middle base mismatch ref '-' for FAM131B:7:143053877:->C at 7:143053877. Returning None.
#   >>> Skipping mutation 230/71477 (FAM131B:7:143053877:->C): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 240/71477 (MCM7:7:99696705:->T): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 278/71477 (PBLD:10:70048359:CCTGTGTTTTCAACTTG>-): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 308/71477 (RPH3A:12:113303262:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   >>> Skipping mutation 386/71477 (KRTAP1-1:17:39197262:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   >>> Skipping mutation 390/71477 (RUNDC1:17:41143406:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   >>> Skipping mutation 405/71477 (COL5A3:19:10080331:->T): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 411/71477 (ZNF536:19:30935349:->T): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 417/71477 (PSG10P:19:43348706:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   >>> Skipping mutation 470/71477 (OBSCN:1:228558786:C>-): Not SNV or non-ACGT ref/alt. Ref='C', Alt='-'
#   >>> Skipping mutation 481/71477 (ZSWIM5:1:45508890:C>-): Not SNV or non-ACGT ref/alt. Ref='C', Alt='-'
#   >>> Skipping mutation 583/71477 (PCDHB3:5:140480154:G>-): Not SNV or non-ACGT ref/alt. Ref='G', Alt='-'
#   >>> Skipping mutation 604/71477 (FRK:6:116289825:TTC>-): Invalid context fetched or returned: 'None' (Type: <class 'NoneType'>)
#   >>> Skipping mutation 608/71477 (SHPRH:6:146276182:A>-): Not SNV or non-ACGT ref/alt. Ref='A', Alt='-'
#
# Debug (TrinucModel.fit): --- Fitting Summary ---
# Debug (TrinucModel.fit): Total mutations input: 71477
# Debug (TrinucModel.fit): Successfully processed: 69288
# Debug (TrinucModel.fit): Skipped - Invalid context fetch/format: 1132
# Debug (TrinucModel.fit): Skipped - Not SNV / Non-ACGT ref/alt: 1057
# Debug (TrinucModel.fit): Skipped - Failed normalization/Invalid context: 0
# Debug (TrinucModel.fit): Skipped - Invalid substitution key: 0
# Debug (TrinucModel.fit): Skipped - Invalid context key (lookup failed): 0
# Debug (TrinucModel.fit): ------------------------
# Debug (TrinucModel.fit): Calculated rates. Total counts: 69288
# Debug (TrinucModel.fit): Mean rate used for normalization: 360.8750
# Debug (TrinucModel.fit): Resulting rates - Min: 0.0776, Max: 4.4586, Mean: 1.0000
# Debug (TrinucModel.fit): Model fitting finished.
# Debug (Analysis.run): Trinucleotide model fitting process completed.
# Debug (Analysis.run): Trinuc rates seem fitted (Min=0.078, Max=4.459, Mean=1.000).
#
# Debug (Analysis.run): Step 3 - Processing genes (sequences and expected counts)...
# Debug (Analysis.run): Pre-grouping observed mutations by gene...
# Debug (Analysis.run): Grouped mutations for 15962 genes.
# Debug (Analysis.run): Iterating through 15962 genes found in the mutation data...
# Debug (Analysis.run): Processing 15962 genes...
# Debug (Calculator.ExpRatio): Calculating expected rates and counts for sequence len=1986...
#   Debug (Calculator.ExpRatio): Skipping site at pos 0 (codon ATG) due to 'N' in context 'NAT'.
#   Debug (Calculator.ExpRatio): Skipping site at pos 1985 (codon GCC) due to 'N' in context 'CCN'.
# Debug (Calculator.ExpRatio): --- Calculation Summary ---
#   Codons processed: 662
#   Sites processed: 1986
#   Sites skipped (N in codon): 0
#   Sites skipped (N in context): 2
#   Mutations considered: 5952
#   Mutations with zero rate: 0
#   Total expected rate sum: 6678.0464
#   Total expected count sum: 5952.0
#   Rates Sums per impact:
#     - synonymous: 1808.9394
#     - missense: 4462.5120
#     - nonsense: 350.4981
#     - stop_loss: 56.0970
#     - other: 0.0000
#   Counts per impact:
#     - synonymous: 1356.0
#     - missense: 4269.0
#     - nonsense: 235.0
#     - stop_loss: 92.0
#     - other: 0.0
# Debug (Calculator.ExpRatio): --------------------------
# Debug (Calculator.ExpRatio): Calculating expected rates and counts for sequence len=18456...
#   Debug (Calculator.ExpRatio): Skipping site at pos 0 (codon ATG) due to 'N' in context 'NAT'.
#   Debug (Calculator.ExpRatio): Skipping site at pos 18455 (codon ATT) due to 'N' in context 'TTN'.
# Debug (Calculator.ExpRatio): --- Calculation Summary ---
#   Codons processed: 6152
#   Sites processed: 18456
#   Sites skipped (N in codon): 0
#   Sites skipped (N in context): 2
#   Mutations considered: 55362
#   Mutations with zero rate: 0
#   Total expected rate sum: 57373.5643
#   Total expected count sum: 55362.0
#   Rates Sums per impact:
#     - synonymous: 12988.9990
#     - missense: 39614.1018
#     - nonsense: 3781.9106
#     - stop_loss: 988.5528
#     - other: 0.0000
#   Counts per impact:
#     - synonymous: 11995.0
#     - missense: 39394.0
#     - nonsense: 2522.0
#     - stop_loss: 1451.0
#     - other: 0.0
# Debug (Calculator.ExpRatio): --------------------------
#   Debug (GetCDS): Gene 'NEBL' - CDS length 5605 not multiple of 3. Trimming last 1 bases.
# Debug (Calculator.ExpRatio): Calculating expected rates and counts for sequence len=5604...
#   Debug (Calculator.ExpRatio): Skipping site at pos 0 (codon ATG) due to 'N' in context 'NAT'.
# Debug (Calculator.ExpRatio): --- Calculation Summary ---
#   Codons processed: 1868
#   Sites processed: 5604
#   Sites skipped (N in codon): 0
#   Sites skipped (N in context): 2
#   Mutations considered: 16806
#   Mutations with zero rate: 0
#   Total expected rate sum: 16471.8781
#   Total expected count sum: 16806.0
#   Rates Sums per impact:
#     - synonymous: 3499.4998
#     - missense: 11309.3620
#     - nonsense: 1161.8677
#     - stop_loss: 501.1486
#     - other: 0.0000
#   Counts per impact:
#     - synonymous: 3453.0
#     - missense: 11717.0
#     - nonsense: 816.0
#     - stop_loss: 820.0
#     - other: 0.0
# Debug (Calculator.ExpRatio): --------------------------
#   Debug (GetCDS): Gene 'ERCC6' - CDS length 7604 not multiple of 3. Trimming last 2 bases.
# Debug (Calculator.ExpRatio): Calculating expected rates and counts for sequence len=7602...
# Debug (Calculator.ExpRatio): --- Calculation Summary ---
#   Codons processed: 2534
#   Sites processed: 7602
#   Sites skipped (N in codon): 0
#   Sites skipped (N in context): 2
#   Mutations considered: 22800
#   Mutations with zero rate: 0
#   Total expected rate sum: 23695.1742
#   Total expected count sum: 22800.0
#   Rates Sums per impact:
#     - synonymous: 5378.3388
#     - missense: 16202.3027
#     - nonsense: 1639.4402
#     - stop_loss: 475.0925
#     - other: 0.0000
#   Counts per impact:
#     - synonymous: 4902.0
#     - missense: 16179.0
#     - nonsense: 1086.0
#     - stop_loss: 633.0
#     - other: 0.0
# Debug (Calculator.ExpRatio): --------------------------
#   Debug (GetCDS): Gene 'DIP2C' - CDS length 9391 not multiple of 3. Trimming last 1 bases.
# Debug (Calculator.ExpRatio): Calculating expected rates and counts for sequence len=9390...
# Debug (Calculator.ExpRatio): --- Calculation Summary ---
#   Codons processed: 3130
#   Sites processed: 9390
#   Sites skipped (N in codon): 0
#   Sites skipped (N in context): 2
#   Mutations considered: 28164
#   Mutations with zero rate: 0
#   Total expected rate sum: 32076.5029
#   Total expected count sum: 28164.0
#   Rates Sums per impact:
#     - synonymous: 8110.4510
#     - missense: 21631.1770
#     - nonsense: 1792.1192
#     - stop_loss: 542.7558
#     - other: 0.0000
#   Counts per impact:
#     - synonymous: 6913.0
#     - missense: 19390.0
#     - nonsense: 1090.0
#     - stop_loss: 771.0
#     - other: 0.0
# Debug (Calculator.ExpRatio): --------------------------
#   Debug (GetCDS): Gene 'ATM' - CDS length 24287 not multiple of 3. Trimming last 2 bases.
#   Debug (GetCDS): Gene 'USP28' - CDS length 17023 not multiple of 3. Trimming last 1 bases.
#   Debug (GetCDS): Gene 'SPRY3' - CDS has too many 'N' bases (864/1728 = 0.50 > 0.1).
#   Debug (GetCDS): Gene 'CRLF2' - CDS has too many 'N' bases (2233/4467 = 0.50 > 0.1).
#   Debug (GetCDS): Gene 'IL9R' - CDS has too many 'N' bases (5085/10170 = 0.50 > 0.1).
#   Debug (GetCDS): Gene 'DHRSX' - CDS has too many 'N' bases (561/5400 = 0.10 > 0.1).
#   Debug (GetCDS): Gene 'VAMP7' - CDS has too many 'N' bases (2154/4308 = 0.50 > 0.1).
#
# Debug (Analysis.run): --- Gene Processing Summary ---
# Debug (Analysis.run): Genes processed successfully: 15520
# Debug (Analysis.run): Genes skipped (no annotation info): 436
# Debug (Analysis.run): Genes skipped (CDS extraction failed): 6
# Debug (Analysis.run): Genes with zero expected mutations: 0
# Debug (Analysis.run): Total expected counts stored for 15520 genes.
# Debug (Analysis.run): Sanity Check - Total expected synonymous mutations across all genes: 78424049.3911
#
# Debug (Analysis.run): Step 4 - Fitting negative binomial model (SKIPPED - No covariates provided)...
#
# Debug (Analysis.run): Step 5 - Testing for selection...
# Debug (Analysis.run): Selection testing completed. Results shape: (15520, 20)
# Debug (Analysis.run): Selection results head:
#      gene_name  n_syn  n_mis  n_non  n_spl       exp_syn       exp_mis  \
# 31        KRAS      0    112      1      0    826.263942   2825.355040
# 1067      TP53      7     94     25      6   7831.903014  20884.320055
# 1072     KEAP1      1     46      8      1   6721.643228  16909.652927
# 1786      EGFR      0     44      1      0  14919.836508  39904.817458
# 1499     STK11      2     21     14      7   2934.874957   6987.624524
#
#           exp_non  exp_spl  exp_syn_counts  exp_mis_counts  exp_non_counts  \
# 31     256.903360        0           917.0          3239.0           223.0
# 1067  1598.520263        0          6372.0         18532.0           970.0
# 1072  1378.554901        0          5452.0         14674.0           808.0
# 1786  3586.025632        0         12340.0         38252.0          2281.0
# 1499   545.997922        0          2166.0          6104.0           332.0
#
#       exp_spl_counts  dnds_global   dnds_mis   dnds_non         lr  \
# 31                 0          NaN        NaN        NaN  53.674279
# 1067               0     6.220540   5.035896  17.498109  38.929922
# 1072               0    20.214686  18.285153  39.006895  27.026600
# 1786               0          NaN        NaN        NaN  26.545350
# 1499               0     8.180975   4.410109  37.626745  16.450510
#
#            p_value       q_value  significant
# 31    2.366411e-13  3.672670e-09         True
# 1067  4.392953e-10  3.408932e-06         True
# 1072  2.006748e-07  9.988036e-04         True
# 1786  2.574236e-07  9.988036e-04         True
# 1499  4.993675e-05  1.550037e-01        False
#
# Debug (Analysis.run): Step 6 - Calculating global dN/dS...
# Debug (Global dN/dS): Calculating global ratios...
# Debug (Global dN/dS): Summing observed counts from 15962 genes...
# Debug (Global dN/dS): Summed observed counts from 15520 relevant genes.
# Debug (Global dN/dS): Summing expected counts from 15520 genes...
# Debug (Global dN/dS): --- Totals ---
#   Observed: Syn=15207, Mis=42177, Non=3450, Spl=1298
#   Expected: Syn=78424049.391, Mis=213627037.265, Non=19217835.051, Spl=0.000
# Debug (Global dN/dS): Synonymous rate (Obs/Exp): 0.0002
# Debug (Global dN/dS): Missense rate: 0.0002, dN/dS_missense: 1.0182
# Debug (Global dN/dS): Nonsense rate: 0.0002, dN/dS_nonsense: 0.9258
# Debug (Global dN/dS): Splice_site rate: N/A (Exp=0), dN/dS_splice_site: NaN
# Debug (Global dN/dS): Global NonSyn rate: 0.0002, Global dN/dS: 1.0393
# Debug (Global dN/dS): Finished calculation.
# Debug (Analysis.run): Global dN/dS calculated:
#   - missense: 1.0182
#   - nonsense: 0.9258
#   - splice_site: nan
#   - global: 1.0393
#   - n_syn: 15207
#   - n_mis: 42177
#   - n_non: 3450
#   - n_spl: 1298
#   - exp_syn: 78424049.3911
#   - exp_mis: 213627037.2650
#   - exp_non: 19217835.0509
#   - exp_spl: 0.0000
#
# Debug (Analysis.run): Step 7 - Saving results...
# Debug (Analysis.run): Output directory: results_directory_debug_final_2
# Debug (Analysis.run): Saved gene results to results_directory_debug_final_2/gene_results.csv
# Debug (Analysis.run): Saved global dN/dS to results_directory_debug_final_2/global_dnds.csv
#
# --- Debug (Analysis.run): Analysis run method complete! ---
#
# --- Debug: dN/dS Analysis Run Finished ---
# Debug: Analysis completed. Results DataFrame shape: (15520, 20)
# Debug: Results columns: ['gene_name', 'n_syn', 'n_mis', 'n_non', 'n_spl', 'exp_syn', 'exp_mis', 'exp_non', 'exp_spl', 'exp_syn_counts', 'exp_mis_counts', 'exp_non_counts', 'exp_spl_counts', 'dnds_global', 'dnds_mis', 'dnds_non', 'lr', 'p_value', 'q_value', 'significant']
# Debug: First 5 rows of results:
#      gene_name  n_syn  n_mis  n_non  n_spl       exp_syn       exp_mis  \
# 31        KRAS      0    112      1      0    826.263942   2825.355040
# 1067      TP53      7     94     25      6   7831.903014  20884.320055
# 1072     KEAP1      1     46      8      1   6721.643228  16909.652927
# 1786      EGFR      0     44      1      0  14919.836508  39904.817458
# 1499     STK11      2     21     14      7   2934.874957   6987.624524
#
#           exp_non  exp_spl  exp_syn_counts  exp_mis_counts  exp_non_counts  \
# 31     256.903360        0           917.0          3239.0           223.0
# 1067  1598.520263        0          6372.0         18532.0           970.0
# 1072  1378.554901        0          5452.0         14674.0           808.0
# 1786  3586.025632        0         12340.0         38252.0          2281.0
# 1499   545.997922        0          2166.0          6104.0           332.0
#
#       exp_spl_counts  dnds_global   dnds_mis   dnds_non         lr  \
# 31                 0          NaN        NaN        NaN  53.674279
# 1067               0     6.220540   5.035896  17.498109  38.929922
# 1072               0    20.214686  18.285153  39.006895  27.026600
# 1786               0          NaN        NaN        NaN  26.545350
# 1499               0     8.180975   4.410109  37.626745  16.450510
#
#            p_value       q_value  significant
# 31    2.366411e-13  3.672670e-09         True
# 1067  4.392953e-10  3.408932e-06         True
# 1072  2.006748e-07  9.988036e-04         True
# 1786  2.574236e-07  9.988036e-04         True
# 1499  4.993675e-05  1.550037e-01        False
#
# --- Debug: Script Execution Complete ---
# Debug (RefGenome): Closing FASTA file: /Users/xbh0403/Desktop/25SP/BENG285/project_2/hg19.fa
# Debug: Closed reference genome file.
